# %%
def count(fname):
    return sum(1 for line in open(fname))

setMeasures = [] #measure files settings

#Open settings file
settingsPath = "C:/Users/debora.romagnolo/Desktop/Ziggurat/Python/settingsFile.txt" #settings file patch
settingsFile = open(settingsPath, 'r') 

#record all rows in the settings file into a list
settingsRows = settingsFile.readlines() 
settingsFile.close() 

# PATHS #
rawDataPath = settingsRows[0] #Raw Data Folder folder: where all txt files are
plant1Path = settingsRows[1]
plant2Path = settingsRows[2]
tagsPath = settingsRows[3].strip() #tags of workshop plan - pre defined
resultsPath = settingsRows[4] #batch folder

# INPUTS #
# settings #
input1 = [4,10,14,15,18,21,30,31,32,33,34]
input2 = [3,23,24,25,26,28,29,30,31,32,35,36]
tag1 =	[0,1,3,6,9,10,5,8,2,4,7]
tag2 = [17,18,19,23,14,16,20,22,21,15,13,24]
raw1 = rawDataPath.strip() + "/Plant 1"
raw2 = rawDataPath.strip() + "/Plant 2"
result1 = resultsPath.strip() + "/Plant 1 Batch"
result2 = resultsPath.strip() + "/Plant 2 Batch"

workshopTags = [] #To put TAG <-> FILE association: selection of measures 


print("##############################################################################################")
print("#################### ZIGGURAT - ENERGY CONSUMPTION REPORTS - v. 1.1. #########################")
print("##############################################################################################")

print("\n##############################################################################################")
print("############################ TECUMSEH PRODUCTS COMPANY - BRAZIL ##############################")
print("############# Developed by Debora R. Romagnolo - Maintenance Technical Assistant #############")
print("##############################################################################################")

print("\nThis script is to generate a consumption report of a batch of days from Smart 32 txt files")
print("\nTo use this script, follow the steps above:")
print("1. you need to export txt files from Smart 32 and put it in the raw data folder")
print("2. delete all batch files in results folder")
print("3. set tags and measures pre defined in the files plant1/plant2 and workshoptags")
print("4. put all the settings in the settings file and save it (without position edits)")


print("\n\t\t\t\t\tCurrent Settings: ")
print("\nMain settings path: " , settingsPath)
print("Raw Data folder: ", rawDataPath)
print("Plant 1 folder:" ,raw1)
print("Plant 2 folder:" ,raw2)
print("\n##############################################################################################")
print("###################################### MEASURES ##############################################")
print("##############################################################################################\n")

#####################################################################################################
#open measure names file and return a list with selected files that will be used to the batch generation

def readPlantFile(plantFile):
    
    measureOlist = [] #zera para preencher de novo
    
    fileMeasureList = open(plantFile.strip(), 'r') #open the pre defined measure name file
    measureNamesList = fileMeasureList.readlines() 
    
    print("File:" , plantFile)

    #fileMeasureList.close()
    n = count(plantFile.strip()) #count up the number of rows in the measure names file

    print(n , "measures has been found!\n")
    
    for i in range (0,n): #row 4 = first name of the list
        measureRow = measureNamesList[i].split("\t")  #
        measureOlist.append(measureRow[0]) #complete list with measures names

    return measureOlist #return the selection of measures

#####################################################################################################

#measureOlists: Lists of selected measures
plant1Measures = readPlantFile(plant1Path)
plant2Measures = readPlantFile(plant2Path)

print("\n##############################################################################################")
print("##################################### WORKSHOP PLAN TAGS #####################################")
print("##############################################################################################\n")

#open tags file
tagsFile = open(tagsPath, 'r')
tagsRows = tagsFile.readlines()

for i in range (0,count(tagsPath)):
    print(tagsRows[i].strip()) #shows complete list of tags
# Out:
# ##############################################################################################
# #################### ZIGGURAT - ENERGY CONSUMPTION REPORTS - v. 1.1. #########################
# ##############################################################################################
#
# ##############################################################################################
# ############################ TECUMSEH PRODUCTS COMPANY - BRAZIL ##############################
# ############# Developed by Debora R. Romagnolo - Maintenance Technical Assistant #############
# ##############################################################################################
#
# This script is to generate a consumption report of a batch of days from Smart 32 txt files
#
# To use this script, follow the steps above:
# 1. you need to export txt files from Smart 32 and put it in the raw data folder
# 2. delete all batch files in results folder
# 3. set tags and measures pre defined in the files plant1/plant2 and workshoptags
# 4. put all the settings in the settings file and save it (without position edits)
#
# 					Current Settings:
#
# Main settings path:  C:/Users/debora.romagnolo/Desktop/Ziggurat/Python/settingsFile.txt
# Raw Data folder:  C:/Users/debora.romagnolo/Desktop/Ziggurat/RawData
#
# Plant 1 folder: C:/Users/debora.romagnolo/Desktop/Ziggurat/RawData/Plant 1
# Plant 2 folder: C:/Users/debora.romagnolo/Desktop/Ziggurat/RawData/Plant 2
#
# ##############################################################################################
# ###################################### MEASURES ##############################################
# ##############################################################################################
#
# File: C:/Users/debora.romagnolo/Desktop/Ziggurat/Name Settings/plant1.txt
#
# 35 measures has been found!
#
# File: C:/Users/debora.romagnolo/Desktop/Ziggurat/Name Settings/plant2.txt
#
# 42 measures has been found!
#
#
# ##############################################################################################
# ##################################### WORKSHOP PLAN TAGS #####################################
# ##############################################################################################
#
# PI - Compressor
# PI - Laboratórios
# PI - Manutenção
# PI - MBU-1 (F1 - Fornos)
# PI - MBU-1 (F1 - F. Eletromotriz)
# PI - MBU-1 (F1)
# PI - MBU-1 (F2 - Fornos)
# PI - MBU-1 (F2 - F. Eletromotriz)
# PI - MBU-1 (F2)
# PI - MBU-1 Total
# PI - MBU-2
# PI - Total (com Fundição)
# PI - Total (sem Fundição)
# PII - Administração
# PII - Compressor
# PII - MBU-3 MBU-3 USIN
# PII - MBU-3 MONT. MBU-3 / P.FINAL
# PII - MBU-3 PIT III
# PII - MBU-3 Total
# PII - MBU-4
# PII - MBU-5 MBU-5 USIN. DESBASTE RG / PIT NOVO
# PII - MBU-5 MONT. / USIN TP / P. FINAL / U.C.
# PII - MBU-5 PIT VELHO
# PII - MBU-5 Total
# PII - RH
# PII - Total
# Total - PII + PI (com Fundição)
# Total - PII + PI (sem Fundição)

# %%
#############################################################################################

#inputSet = measure settings list
#measures = measureOlist obtained in the read plant file function previously
#tagSet = selected tags, this is a required input (with selected measures s)

def configs(inputSet, measures, tagSet): 
    
    workshopTags = []
    selectedIndex = []

    print("\n\t\t\t\tFILES:\n")
    
    #open tags file
    tagsFile = open(tagsPath, 'r')
    tagsRows = tagsFile.readlines()
    
    maxSet = len(inputSet)
    maxTag = len(tagSet)

    for i in range(0,maxSet):
        index = inputSet[i]
        selectedIndex.append(measures[index].strip()) #measures list with set points
        print(measures[index].strip())

    print("\n\t\t\t\tTAGS")

    for i in range (0,maxTag):
        workshopTags.append(tagsRows[tagSet[i]].strip()) #tag list from setings list
        print(tagsRows[tagSet[i]].strip())
        
    return workshopTags, selectedIndex

############################################################################################

    
workshop1, index1 = configs(input1, plant1Measures, tag1)
workshop2, index2 = configs(input2, plant2Measures, tag2)
# Out:
# 				FILES:
#
# GATE MED 2_[2] COMPRESSOR.txt
# GATE MED 2_[8] GERAL LABORATORIOS.txt
# Medições Virtuais_[11] F1 - FORNOS.txt
# Medições Virtuais_[12] F2 - FORNOS.txt
# Medições Virtuais_[3] MBU1.txt
# Medições Virtuais_[6] MBU2.txt
# SMART BASE 1_[5] FUNDIÇÃO 1.txt
# SMART BASE 1_[6] FUNDIÇÃO 2.txt
# SMART BASE 1_[7] MANUT E FERRAMENTARIA.txt
# SMART BASE 1_[8] FORÇA ELETRO MOTRIZ FUND. 1.txt
# SMART BASE 1_[9] FORÇA ELETRO MOTRIZ FUND. 2.txt
#
# 				TAGS
# PI - Compressor
# PI - Laboratórios
# PI - MBU-1 (F1 - Fornos)
# PI - MBU-1 (F2 - Fornos)
# PI - MBU-1 Total
# PI - MBU-2
# PI - MBU-1 (F1)
# PI - MBU-1 (F2)
# PI - Manutenção
# PI - MBU-1 (F1 - F. Eletromotriz)
# PI - MBU-1 (F2 - F. Eletromotriz)
#
# 				FILES:
#
# GATE_A_[1] SE PIT-MBU III-TRAFO 1.txt
# Medições Virtuais_[0] MBU_3.txt
# Medições Virtuais_[1] MBU_4.txt
# Medições Virtuais_[2] MBU_5.txt
# Medições Virtuais_[3] AR COMPRIMIDO.txt
# Medições Virtuais_[5] MONTAGEM MBU_III.txt
# Medições Virtuais_[6] USIN.RG DESBASTE+PIT NOVO.txt
# Medições Virtuais_[7] PIT VELHO.txt
# Medições Virtuais_[8] MBU V 6 TRAFOS.txt
# Medições Virtuais_[9] NOVA USIN MBU III.txt
# SMART_BASE_[2] ADMINISTRACAO.txt
# SMART_BASE_[3] PRIM.1-TRAFO RH.txt
#
# 				TAGS
# PII - MBU-3 PIT III
# PII - MBU-3 Total
# PII - MBU-4
# PII - MBU-5 Total
# PII - Compressor
# PII - MBU-3 MONT. MBU-3 / P.FINAL
# PII - MBU-5 MBU-5 USIN. DESBASTE RG / PIT NOVO
# PII - MBU-5 PIT VELHO
# PII - MBU-5 MONT. / USIN TP / P. FINAL / U.C.
# PII - MBU-3 MBU-3 USIN
# PII - Administração
# PII - RH

# %%
#Function to count rows of a file
def count(fname):
    return sum(1 for line in open(fname))

import xlwt

#INPUTS#
#inputSet = list of selected measures
#tagSet = list of selected tags
#measures = list measureOlist, which contains only the selected measure file names
#rawFolder = raw data path folder (raw 1 or raw2)
#selected = selected index (result of configs function)
#tags = workshop tags (result of configs function)

#############################################################################################
def batchGenerator(inputSet, rawFolder, selected, tags, results):
    
    maxSet = len(inputSet)
    
    #Lists initialization
    measureDay = [] #consumption of a day (by hours) records are saved in this list
    measureFP = 1 #column increment
    soma = 0 #the sum of consumption in a day is recorded in this variable
    sumDay = [] #final product: [day1, sum of the day1, day2, sum of the day2 ...]
    numLin = 0
    plant = []
    
    rowsCount = 0

    wb = xlwt.Workbook()
    ws = wb.add_sheet('Batch Data')


    for i in range (0, maxSet):
    
        path = rawFolder.strip() + "/" + selected[i]
        file = open(path, 'r') #open file

        print("file name:" , selected[i])
        
        plant.append(tags[i])
        
        numLin = count(path)
        fileList = file.readlines() #list of that file opened
        
        dates = fileList[17] #days registered in that file opened
        datesList = dates.split() #split the recorded row in strings (each string is a date)
        
        numDays = len(datesList) #number of strings splited = number of days in the opened file
        print("days in this file: " , numDays)

        for j in range(0,numDays):

            measureDay.append(datesList[j]) #add date in the first element of the list
            sumDay.append(datesList[j]) #add date in the first element of the list with consumption sum

            for k in range(19, numLin): #row 19 is the first line with measures
                infos = fileList[k] #put the currently row in a list
                infoList = infos.split("\t") #split in \t

                transition = float(infoList[measureFP]) #record the measure in the referred colum (every loop needs an increment of 2 in the column to synchronize with the currently day (j)) 
                measureDay.append(transition) #record in the day measure list the currently measure
                soma = soma + transition

            measureFP = measureFP + 2
            sumDay.append("%.2f" % soma) #the sum result is recorded in the second element of the list sumDay


            ws.write(rowsCount, 2, tags[i]) #column 2
            ws.write(rowsCount, 3, soma) #column 4
            ws.write(rowsCount, 0, datesList[j]) #column 1

            soma = 0

            rowsCount = rowsCount + 1


        wb.save(results.strip() + '/batch.xls')

        plant.append(sumDay)
        
        #reset lists and variables for a new day loop
        measureDay = [] 
        infos = []
        infoList = []
        transition = ""
        sumDay = []
        measureFP = 1
        
    return plant
###########################################################################################       

#Batch for plant 1 and plant 2 files: [fileName, DAY LIST]
plant1 = batchGenerator(input1, raw1, index1, workshop1, result1)
plant2 = batchGenerator(input2, raw2, index2, workshop2, result2)
# Out:
# file name: GATE MED 2_[2] COMPRESSOR.txt
# days in this file:  10
# file name: GATE MED 2_[8] GERAL LABORATORIOS.txt
# days in this file:  10
# file name: Medições Virtuais_[11] F1 - FORNOS.txt
# days in this file:  10
# file name: Medições Virtuais_[12] F2 - FORNOS.txt
# days in this file:  10
# file name: Medições Virtuais_[3] MBU1.txt
# days in this file:  10
# file name: Medições Virtuais_[6] MBU2.txt
# days in this file:  10
# file name: SMART BASE 1_[5] FUNDIÇÃO 1.txt
# days in this file:  10
# file name: SMART BASE 1_[6] FUNDIÇÃO 2.txt
# days in this file:  10
# file name: SMART BASE 1_[7] MANUT E FERRAMENTARIA.txt
# days in this file:  10
# file name: SMART BASE 1_[8] FORÇA ELETRO MOTRIZ FUND. 1.txt
# days in this file:  10
# file name: SMART BASE 1_[9] FORÇA ELETRO MOTRIZ FUND. 2.txt
# days in this file:  10
# file name: GATE_A_[1] SE PIT-MBU III-TRAFO 1.txt
# days in this file:  10
# file name: Medições Virtuais_[0] MBU_3.txt
# days in this file:  10
# file name: Medições Virtuais_[1] MBU_4.txt
# days in this file:  10
# file name: Medições Virtuais_[2] MBU_5.txt
# days in this file:  10
# file name: Medições Virtuais_[3] AR COMPRIMIDO.txt
# days in this file:  10
# file name: Medições Virtuais_[5] MONTAGEM MBU_III.txt
# days in this file:  10
# file name: Medições Virtuais_[6] USIN.RG DESBASTE+PIT NOVO.txt
# days in this file:  10
# file name: Medições Virtuais_[7] PIT VELHO.txt
# days in this file:  10
# file name: Medições Virtuais_[8] MBU V 6 TRAFOS.txt
# days in this file:  10
# file name: Medições Virtuais_[9] NOVA USIN MBU III.txt
# days in this file:  10
# file name: SMART_BASE_[2] ADMINISTRACAO.txt
# days in this file:  10
# file name: SMART_BASE_[3] PRIM.1-TRAFO RH.txt
# days in this file:  10

# %%
import xlwt

def toFloat(listStr):
    n = len(listStr)
    for i in range(1,n,2):
        listStr[i] = float(listStr[i])
    return listStr

def addAreaDay(areaConsumption, result):
    for i in range(1,len(areaConsumption), 2):
        result[i] = result[i] + areaConsumption[i]
    return result

num = len(plant1)
num2 = len(plant2)

#for i in range (0, num):
    #print(plant1[i])

max1 = len(plant1)
max2 = len(plant2)

#tag Names positions

print("\nPlant 1 - Positions\n")

for i in range(0,max1,2):

  print(i,":" , plant1[i])

print("\nPlant 2 - Positions\n")

for i in range(0,max2,2):
  print(i, ":", plant2[i])

#sum without foundry - Plant1
plant1sum = []

withoutFoundry = []

batch = plant1[1] #compressor
plant1sum = toFloat(batch)
batch = toFloat(plant1[3]) #labs
plant1sum = addAreaDay(batch, plant1sum) #labs + compressor
batch = toFloat(plant1[11]) #mbu2
plant1sum = addAreaDay(batch, plant1sum) #labs + compressor + mbu2
batch = toFloat(plant1[17]) #maintenance/tooling
plant1sum = addAreaDay(batch, plant1sum) #labs + compressor + mbu2 + maintenance/tooling

for i in range(0,len(plant1sum)):
    withoutFoundry.append(plant1sum[i])

batch = toFloat(plant1[9]) #mbu1
plant1sum = addAreaDay(batch, plant1sum) #total with foundry

print("Plant 1 w/ Foundry:", withoutFoundry)
print("Plant 1 Total: " , plant1sum)

plant2sum = []

batch = plant2[3] #mbu3
plant2sum = toFloat(batch)
batch = toFloat(plant2[5]) #mbu4
plant2sum = addAreaDay(batch, plant2sum)
batch = toFloat(plant2[7]) #mbu5
plant2sum = addAreaDay(batch, plant2sum)
batch = toFloat(plant2[9]) #compressor
plant2sum = addAreaDay(batch, plant2sum) 
batch = toFloat(plant2[21]) #ADM
plant2sum = addAreaDay(batch, plant2sum)
batch = toFloat(plant2[23]) #RH
plant2sum = addAreaDay(batch, plant2sum)

print("Plant 2:" , plant2sum)

listLenght = len(plant1sum)

tecumsehWithoutFoundry = []
tecumseh = []

for i in range(0, listLenght):
    tecumsehWithoutFoundry.append(withoutFoundry[i]) #without foundry
    tecumseh.append(plant1sum[i]) #with foundry

#tecumseh total

for i in range(1, listLenght,2):
    tecumsehWithoutFoundry[i] = tecumsehWithoutFoundry[i] + plant2sum[i]
    tecumseh[i] = tecumseh[i] + plant2sum[i]
    
    
print("total Tecumseh:", tecumseh)
print("without Foundry:" , tecumsehWithoutFoundry)
# Out:
# Plant 1 - Positions
#
# 0 : PI - Compressor
# 2 : PI - Laboratórios
# 4 : PI - MBU-1 (F1 - Fornos)
# 6 : PI - MBU-1 (F2 - Fornos)
# 8 : PI - MBU-1 Total
# 10 : PI - MBU-2
# 12 : PI - MBU-1 (F1)
# 14 : PI - MBU-1 (F2)
# 16 : PI - Manutenção
# 18 : PI - MBU-1 (F1 - F. Eletromotriz)
# 20 : PI - MBU-1 (F2 - F. Eletromotriz)
#
# Plant 2 - Positions
#
# 0 : PII - MBU-3 PIT III
# 2 : PII - MBU-3 Total
# 4 : PII - MBU-4
# 6 : PII - MBU-5 Total
# 8 : PII - Compressor
# 10 : PII - MBU-3 MONT. MBU-3 / P.FINAL
# 12 : PII - MBU-5 MBU-5 USIN. DESBASTE RG / PIT NOVO
# 14 : PII - MBU-5 PIT VELHO
# 16 : PII - MBU-5 MONT. / USIN TP / P. FINAL / U.C.
# 18 : PII - MBU-3 MBU-3 USIN
# 20 : PII - Administração
# 22 : PII - RH
# Plant 1 w/ Foundry: ['02/04/2019', 57906.9, '03/04/2019', 59205.5, '04/04/2019', 59554.99999999999, '05/04/2019', 60558.0, '06/04/2019', 50860.299999999996, '07/04/2019', 12180.9, '08/04/2019', 18839.2, '09/04/2019', 38402.2, '10/04/2019', 59316.899999999994, '11/04/2019', 59760.299999999996]
# Plant 1 Total:  ['02/04/2019', 245273.0, '03/04/2019', 237434.0, '04/04/2019', 247952.8, '05/04/2019', 262036.5, '06/04/2019', 192947.09999999998, '07/04/2019', 113843.09999999999, '08/04/2019', 239851.40000000002, '09/04/2019', 230621.59999999998, '10/04/2019', 250827.3, '11/04/2019', 232652.69999999998]
# Plant 2: ['02/04/2019', 132672.30000000002, '03/04/2019', 122237.20000000001, '04/04/2019', 135566.8, '05/04/2019', 122353.7, '06/04/2019', 103869.3, '07/04/2019', 47224.799999999996, '08/04/2019', 216348.30000000002, '09/04/2019', 174985.6, '10/04/2019', 216142.1, '11/04/2019', 135285.19999999998]
# total Tecumseh: ['02/04/2019', 377945.30000000005, '03/04/2019', 359671.2, '04/04/2019', 383519.6, '05/04/2019', 384390.2, '06/04/2019', 296816.39999999997, '07/04/2019', 161067.9, '08/04/2019', 456199.70000000007, '09/04/2019', 405607.19999999995, '10/04/2019', 466969.4, '11/04/2019', 367937.89999999997]
# without Foundry: ['02/04/2019', 190579.2, '03/04/2019', 181442.7, '04/04/2019', 195121.8, '05/04/2019', 182911.7, '06/04/2019', 154729.6, '07/04/2019', 59405.7, '08/04/2019', 235187.50000000003, '09/04/2019', 213387.8, '10/04/2019', 275459.0, '11/04/2019', 195045.49999999997]

# %%
for i in range(0, len(tecumseh),2):
    print(tecumseh[i],"\t", tecumseh[i+1])
    print(tecumsehWithoutFoundry[i], "\t", tecumsehWithoutFoundry[i+1])
    print(withoutFoundry[i],"\t", withoutFoundry[i+1])
    print(plant1sum[i],"\t", plant1sum[i+1])
    print(plant2sum[i] ,"\t", plant2sum[i+1])
    print("\n")
# Out:
# 02/04/2019 	 377945.30000000005
# 02/04/2019 	 190579.2
# 02/04/2019 	 57906.9
# 02/04/2019 	 245273.0
# 02/04/2019 	 132672.30000000002
#
#
# 03/04/2019 	 359671.2
# 03/04/2019 	 181442.7
# 03/04/2019 	 59205.5
# 03/04/2019 	 237434.0
# 03/04/2019 	 122237.20000000001
#
#
# 04/04/2019 	 383519.6
# 04/04/2019 	 195121.8
# 04/04/2019 	 59554.99999999999
# 04/04/2019 	 247952.8
# 04/04/2019 	 135566.8
#
#
# 05/04/2019 	 384390.2
# 05/04/2019 	 182911.7
# 05/04/2019 	 60558.0
# 05/04/2019 	 262036.5
# 05/04/2019 	 122353.7
#
#
# 06/04/2019 	 296816.39999999997
# 06/04/2019 	 154729.6
# 06/04/2019 	 50860.299999999996
# 06/04/2019 	 192947.09999999998
# 06/04/2019 	 103869.3
#
#
# 07/04/2019 	 161067.9
# 07/04/2019 	 59405.7
# 07/04/2019 	 12180.9
# 07/04/2019 	 113843.09999999999
# 07/04/2019 	 47224.799999999996
#
#
# 08/04/2019 	 456199.70000000007
# 08/04/2019 	 235187.50000000003
# 08/04/2019 	 18839.2
# 08/04/2019 	 239851.40000000002
# 08/04/2019 	 216348.30000000002
#
#
# 09/04/2019 	 405607.19999999995
# 09/04/2019 	 213387.8
# 09/04/2019 	 38402.2
# 09/04/2019 	 230621.59999999998
# 09/04/2019 	 174985.6
#
#
# 10/04/2019 	 466969.4
# 10/04/2019 	 275459.0
# 10/04/2019 	 59316.899999999994
# 10/04/2019 	 250827.3
# 10/04/2019 	 216142.1
#
#
# 11/04/2019 	 367937.89999999997
# 11/04/2019 	 195045.49999999997
# 11/04/2019 	 59760.299999999996
# 11/04/2019 	 232652.69999999998
# 11/04/2019 	 135285.19999999998
